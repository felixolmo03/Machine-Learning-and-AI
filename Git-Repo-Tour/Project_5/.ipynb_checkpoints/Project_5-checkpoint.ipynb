# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

for dirname, _, filenames in os.walk("./"):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# ./Project_5.ipynb
# ./.ipynb_checkpoints/Project_5-checkpoint.ipynb

# %% [markdown]
# # 1. Frame the problem
# Using the customer description, Define the problem your trying to solve in your own words (remember this is not technial but must be specific so the customer understands the project

# %% [markdown]
# We are tasked in developing an algorithm in order to detect certain lowercase cursive letters. The program should be able to detect which letter is in an imported image and output the accuracy of that letter being the predicted letter.

# %% [markdown]
# # 2. Get the Data
# Define how you recieved the data (provided, gathered..)

# %%
import zipfile, os

zip_path = "Cursive.zip"
extract_path = "Git-Repo-Tour/Project_5/Data/Cursive.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# Check a few sample files
for root, dirs, files in os.walk(extract_path):
    print(root, len(files))
    break
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       3 zip_path = "Cursive.zip"
#       4 extract_path = "Git-Repo-Tour/Project_5/Data/Cursive.zip"
# ----> 6 with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#       7     zip_ref.extractall(extract_path)
#       9 # Check a few sample files
#
# File /opt/tljh/user/lib/python3.12/zipfile/__init__.py:1331, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1329 while True:
#    1330     try:
# -> 1331         self.fp = io.open(file, filemode)
#    1332     except OSError:
#    1333         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Cursive.zip'

# %% [markdown]
# # 3. Explore the Data
# Gain insights into the data you have from step 2, making sure to identify any bias

# %%
import glob
import cv2
import random
import matplotlib.pyplot as plt

jpg_files = glob.glob(f"{extract_path}/**/*.jpg", recursive=True)
heic_files = glob.glob(f"{extract_path}/**/*.heic", recursive=True)

print("JPG count:", len(jpg_files))
print("HEIC count:", len(heic_files))


sample = random.choice(jpg_files)
img = cv2.imread(sample)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.title(f"Sample image: {sample.split('/')[-1]}")
plt.axis('off')
plt.show()
# Out:
# JPG count: 600
# HEIC count: 40

# %% [markdown]
# # 4.Prepare the Data
#
#
# Apply any data transformations and explain what and why

# %%
import os
import glob
import cv2
from PIL import Image
import numpy as np

# Paths
base_path = "Data/Cursive"  # relative to Project_5 notebook
subject_folders = [f"S{i}" for i in range(1, 36)]

# Storage
viable_images = []
corrupted_images = []

# Image size
IMG_SIZE = (64, 64)

# Loop through all subject folders
for folder in subject_folders:
    folder_path = os.path.join(base_path, folder)
    if not os.path.exists(folder_path):
        continue
    for img_file in glob.glob(f"{folder_path}/*.*"):
        try:
            # Convert HEIC to JPG if needed
            if img_file.lower().endswith(".HEIC"):
                img_jpg = img_file.replace(".HEIC", ".jpg")
                with Image.open(img_file) as im:
                    im.convert("RGB").save(img_jpg, "JPEG")
                img_file = img_jpg
            
            # Try reading with OpenCV
            img = cv2.imread(img_file, cv2.IMREAD_GRAYSCALE)
            if img is None:
                corrupted_images.append(img_file)
                continue
            
            # Resize and normalize
            img = cv2.resize(img, IMG_SIZE)
            img = img / 255.0
            
            # Store image + label (subject folder)
            viable_images.append((img, folder))
        except Exception as e:
            corrupted_images.append(img_file)

print(f"Total images found: {len(viable_images) + len(corrupted_images)}")
print(f"Viable images: {len(viable_images)}")
print(f"Corrupted/unreadable images: {len(corrupted_images)}")
# Out:
# Total images found: 743
# Viable images: 674
# Corrupted/unreadable images: 69

# %%
import os
import glob
import cv2
from PIL import Image

base_path = "Data/Cursive"
subject_folders = [f"S{i}" for i in range(1, 36)]

viable_images = []
corrupted_images = []
converted_count = 0

for folder in subject_folders:
    folder_path = os.path.join(base_path, folder)
    if not os.path.exists(folder_path):
        continue
    
    for img_file in glob.glob(f"{folder_path}/*.*"):
        # Convert to JPG if not already
        if not img_file.lower().endswith(".jpg"):
            try:
                with Image.open(img_file) as im:
                    im = im.convert("RGB")  # ensure it's RGB
                    new_path = os.path.splitext(img_file)[0] + ".jpg"
                    im.save(new_path, "JPEG")
                    converted_count += 1
                    os.remove(img_file)  # remove original
                    img_file = new_path  # update path to new jpg
            except Exception as e:
                print(f"Failed to convert {img_file}: {e}")
                corrupted_images.append(img_file)
                continue
        
        # Check if OpenCV can read it
        try:
            img = cv2.imread(img_file, cv2.IMREAD_GRAYSCALE)
            if img is None:
                corrupted_images.append(img_file)
            else:
                viable_images.append(img_file)
        except Exception as e:
            corrupted_images.append(img_file)

print(f"Conversion complete! Total files converted to JPG: {converted_count}")
print(f"Total viable images: {len(viable_images)}")
print(f"Total corrupted/unreadable images: {len(corrupted_images)}")
# Out:
# Failed to convert Data/Cursive/S5/IMG_1283.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1283.heic'
# Failed to convert Data/Cursive/S5/IMG_1292.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1292.heic'
# Failed to convert Data/Cursive/S5/IMG_1294.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1294.heic'
# Failed to convert Data/Cursive/S5/IMG_1285.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1285.heic'
# Failed to convert Data/Cursive/S5/IMG_1302.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1302.heic'
# Failed to convert Data/Cursive/S5/IMG_1305.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1305.heic'
# Failed to convert Data/Cursive/S5/IMG_1300.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1300.heic'
# Failed to convert Data/Cursive/S5/IMG_1284.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1284.heic'
# Failed to convert Data/Cursive/S5/IMG_1299.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1299.heic'
# Failed to convert Data/Cursive/S5/IMG_1288.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1288.heic'
# Failed to convert Data/Cursive/S5/IMG_1291.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1291.heic'
# Failed to convert Data/Cursive/S5/IMG_1297.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1297.heic'
# Failed to convert Data/Cursive/S5/IMG_1298.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1298.heic'
# Failed to convert Data/Cursive/S5/IMG_1303.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1303.heic'
# Failed to convert Data/Cursive/S5/IMG_1281.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1281.heic'
# Failed to convert Data/Cursive/S5/IMG_1296.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1296.heic'
# Failed to convert Data/Cursive/S5/IMG_1289.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1289.heic'
# Failed to convert Data/Cursive/S5/IMG_1304.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1304.heic'
# Failed to convert Data/Cursive/S5/IMG_1293.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1293.heic'
# Failed to convert Data/Cursive/S5/IMG_1306.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1306.heic'
# Failed to convert Data/Cursive/S5/IMG_1282.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1282.heic'
# Failed to convert Data/Cursive/S5/IMG_1286.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1286.heic'
# Failed to convert Data/Cursive/S5/IMG_1307.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1307.heic'
# Failed to convert Data/Cursive/S5/IMG_1290.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1290.heic'
# Failed to convert Data/Cursive/S5/IMG_1287.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1287.heic'
# Failed to convert Data/Cursive/S5/IMG_1301.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S5/IMG_1301.heic'
# Failed to convert Data/Cursive/S15/i.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/i.HEIC'
# Failed to convert Data/Cursive/S15/g.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/g.HEIC'
# Failed to convert Data/Cursive/S15/v.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/v.HEIC'
# Failed to convert Data/Cursive/S15/t.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/t.HEIC'
# Failed to convert Data/Cursive/S15/y.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/y.HEIC'
# Failed to convert Data/Cursive/S15/b.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/b.HEIC'
# Failed to convert Data/Cursive/S15/l.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/l.heic'
# Failed to convert Data/Cursive/S15/x.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/x.HEIC'
# Failed to convert Data/Cursive/S15/f.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/f.HEIC'
# Failed to convert Data/Cursive/S15/r.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/r.HEIC'
# Failed to convert Data/Cursive/S15/p.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/p.HEIC'
# Failed to convert Data/Cursive/S15/q.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/q.HEIC'
# Failed to convert Data/Cursive/S15/z.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/z.HEIC'
# Failed to convert Data/Cursive/S15/h.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/h.HEIC'
# Failed to convert Data/Cursive/S15/j.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/j.HEIC'
# Failed to convert Data/Cursive/S15/c.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/c.HEIC'
# Failed to convert Data/Cursive/S15/n.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/n.HEIC'
# Failed to convert Data/Cursive/S15/s.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/s.HEIC'
# Failed to convert Data/Cursive/S15/a.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/a.HEIC'
# Failed to convert Data/Cursive/S15/w.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/w.HEIC'
# Failed to convert Data/Cursive/S15/d.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/d.HEIC'
# Failed to convert Data/Cursive/S15/o.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/o.HEIC'
# Failed to convert Data/Cursive/S15/u.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/u.HEIC'
# Failed to convert Data/Cursive/S15/k.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/k.HEIC'
# Failed to convert Data/Cursive/S15/e.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/e.HEIC'
# Failed to convert Data/Cursive/S15/m.HEIC: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S15/m.HEIC'
# Failed to convert Data/Cursive/S31/d.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S31/d.heic'
# Failed to convert Data/Cursive/S33/C.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S33/C.heic'
# Failed to convert Data/Cursive/S33/G.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S33/G.heic'
# Failed to convert Data/Cursive/S33/I.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S33/I.heic'
# Failed to convert Data/Cursive/S33/B.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S33/B.heic'
# Failed to convert Data/Cursive/S33/F.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S33/F.heic'
# Failed to convert Data/Cursive/S33/D.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S33/D.heic'
# Failed to convert Data/Cursive/S33/A.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S33/A.heic'
# Failed to convert Data/Cursive/S33/E.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S33/E.heic'
# Failed to convert Data/Cursive/S33/L.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S33/L.heic'
# Failed to convert Data/Cursive/S33/H.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S33/H.heic'
# Failed to convert Data/Cursive/S33/K.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S33/K.heic'
# Failed to convert Data/Cursive/S33/M.heic: cannot identify image file '/home/jupyter-1016468/Project_5/Data/Cursive/S33/M.heic'
# Conversion complete! Total files converted to JPG: 0
# Total viable images: 674
# Total corrupted/unreadable images: 69

# %% [markdown]
# # 5. Model the data
# Using selected ML models, experment with your choices and describe your findings. Finish by selecting a Model to continue with

# %% [markdown]
# # 6. Fine Tune the Model
#
# With the select model descibe the steps taken to acheve the best rusults possiable

# %% [markdown]
# # 7. Present
# In a customer faceing Document provide summery of finding and detail approach taken

# %% [markdown]
# # 8. Launch the Model System
# Define your production run code, This should be self susficent and require only your model pramaters
